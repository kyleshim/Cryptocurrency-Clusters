# %%
# Initial imports
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Read `crypto_data.csv` into Pandas
file_path = Path("crypto_data.csv")
df = pd.read_csv(file_path, index_col=0)
df
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42           42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365          365Coin       X11       True   PoW/PoS              NaN
# 404          404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611        SixEleven   SHA-256       True       PoW              NaN
# 808              808   SHA-256       True   PoW/PoS     0.000000e+00
# ...              ...       ...        ...       ...              ...
# XBC      BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# DVTC      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# GIOT     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# PUNK       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# Discard all cryptocurrencies that are not being traded
df['IsTrading'].value_counts()
# Out:
# True     1144
# False     108
# Name: IsTrading, dtype: int64

# %%
trading_df = df[df['IsTrading'] == True]
trading_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 365       365Coin          X11       True   PoW/PoS              NaN
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 611     SixEleven      SHA-256       True       PoW              NaN
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# Remove all rows that have at least one null value
trading_df.isnull().sum()
# Out:
# CoinName             0
# Algorithm            0
# IsTrading            0
# ProofType            0
# TotalCoinsMined    459
# TotalCoinSupply      0
# dtype: int64

# %%
trading_df = trading_df.dropna()
trading_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# 1337    EliteCoin          X13       True   PoW/PoS     2.927942e+10
# BTC       Bitcoin      SHA-256       True       PoW     1.792718e+07
# ...           ...          ...        ...       ...              ...
# ZEPH       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# GAP       Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 808                0
# 1337    314159265359
# BTC         21000000
# ...

# %%
trading_df = trading_df.drop(columns=['IsTrading'], axis=1)
trading_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
# Filter for cryptocurrencies that have been mined
mined_df = trading_df[trading_df['TotalCoinsMined'] > 0]
mined_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# Delete the `CoinName` from the original dataframe
nameless_df = mined_df.drop(columns=['CoinName'], axis=1)
nameless_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
# Convert the remaining features with text values, `Algorithm` and `ProofType`, into numerical data
num_df = pd.get_dummies(nameless_df, columns=['Algorithm','ProofType'])
num_df
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# ...               ...             ...                               ...
# ZEPH     2.000000e+09      2000000000                                 0
# GAP      1.493105e+07       250000000                                 0
# BDX      9.802226e+08      1400222610                                 0
# ZEN      7.296538e+06        21000000                                 0
# XBC      1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %% [markdown]
# The dataframe expanded from 4 columns to 98 columns with the numerical conversion of Algorithm and Proof Type

# %%
# Standardize your dataset
scaler = StandardScaler()
scaled_data = scaler.fit_transform(num_df)

# %%
# Initialize PCA model
pca = PCA(n_components=0.9)

# Get two principal components for the iris data.
scaled_pca = pca.fit_transform(scaled_data)

# %%
pca_df = pd.DataFrame(data=scaled_pca, index=num_df.index)
pca_df
# Out:
#             0         1         2         3             4             5   \
# 42   -0.335099  1.032189 -0.590713  0.001397 -2.653838e-14  6.639677e-14
# 404  -0.318434  1.032331 -0.591126  0.001386 -2.656356e-14  6.662051e-14
# 1337  2.305468  1.656383 -0.683617  0.004731 -3.153905e-14  9.830331e-14
# BTC  -0.145184 -1.320593  0.192813 -0.001229  8.514057e-15 -2.323967e-14
# ETH  -0.151768 -2.036192  0.396182 -0.001705  1.733670e-14 -4.613233e-14
# ...        ...       ...       ...       ...           ...           ...
# ZEPH  2.471251  0.822241 -0.071160 -0.008206  1.047244e-14  3.268675e-14
# GAP  -0.333144  1.032071 -0.590740  0.001399 -2.664739e-14  6.659974e-14
# BDX   0.324349 -2.312308  0.421515 -0.001319  1.694243e-14 -4.711625e-14
# ZEN  -0.149364 -2.049336  0.412968 -0.001745  1.783788e-14 -4.843415e-14
# XBC  -0.289957  0.821195 -0.276327  0.000555 -1.094596e-14  3.100125e-14
#
#                 6         7         8         9   ...            64  \
# ...

# %% [markdown]
# The number of features was reduced from 98 to 74 columns in order preserve 90% explained variance

# %%
# Initialize t-SNE model
tsne = TSNE(learning_rate=200)
# Reduce dimensions
tsne_features = tsne.fit_transform(pca_df)
# The dataset has 2 columns
tsne_features.shape
# Out:
# (532, 2)

# %%
tsne_df = pd.DataFrame(data=tsne_features, columns=['Principal Component 1','Principal Component 2'])
tsne_df
# Out:
#      Principal Component 1  Principal Component 2
# 0                11.592823             -11.005717
# 1                10.838710             -15.485241
# 2                16.008394             -24.140026
# 3                -2.850627              35.598587
# 4               -19.353699               0.741652
# ..                     ...                    ...
# 527              -5.673809              29.850325
# 528              14.009657             -14.513041
# 529             -21.331892              -9.215475
# 530             -18.325312               8.522588
# 531               2.173451              12.206737
#
# [532 rows x 2 columns]

# %%
# Visualize the clusters
plt.scatter(tsne_df['Principal Component 1'], tsne_df['Principal Component 2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %% [markdown]
# There are at least 2 and maybe 3 distinct cluster after the tsne transformation

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=42)
    km.fit(tsne_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow
# Out:
#     k        inertia
# 0   1  187021.328125
# 1   2   96477.054688
# 2   3   51650.460938
# 3   4   34538.210938
# 4   5   29073.800781
# 5   6   23951.500000
# 6   7   19423.652344
# 7   8   15923.085938
# 8   9   13940.982422
# 9  10   11313.779297

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for customer data')
plt.show()

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=42)

# Train the model
model.fit(tsne_df)

# Predict clusters
predictions = model.predict(tsne_df)

# Create return DataFrame with predicted clusters
tsne_df["class"] = model.labels_

# %%
plt.scatter(tsne_df['Principal Component 1'], tsne_df['Principal Component 2'], c=tsne_df['class'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %% [markdown]
# # Recommendations

# %% [markdown]
# Based on the findings it does appear that cryptocurrency can be clustered. The findings show 4 clusters. However, there is one outlier and a large amount of data lost in the processing step. This leads to believe that the best course forward would be to collect more data and re-analyze.
